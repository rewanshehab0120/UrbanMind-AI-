# %%
import os
import sqlite3
import pandas as pd

# 1. المسار الرئيسي للمشروع ومجلد الـ PDF
base_dir = r"D:\Courses\MachineLearning\Depi\Final Project\data\"
pdf_dir = os.path.join(base_dir, "pdf_reports")
os.makedirs(pdf_dir, exist_ok=True)

print(
    f"📌 ضعي ملف الـ PDF الخاص بكِ الآن في هذا المسار ليصل إليه الكود مباشرة:\n👉"
    f" {pdf_dir}\n"
)

# 2. القواميس الخاصة بالبيانات المستخرجة من النشرة
datasets = {
    "cairo_population_districts": [
        # البيانات السكانية التفصيلية لـ 43 حياً
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "مصر الجديدة",
            "district_en": "Heliopolis",
            "males": 73104,
            "females": 74240,
            "total_population": 147344,
            "families_count": 36836,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "النزهة",
            "district_en": "El Nozha",
            "males": 125931,
            "females": 128114,
            "total_population": 254045,
            "families_count": 63511,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "شرق مدينة نصر",
            "district_en": "East Nasr City",
            "males": 336356,
            "females": 360859,
            "total_population": 697215,
            "families_count": 174304,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "غرب مدينة نصر",
            "district_en": "West Nasr City",
            "males": 37567,
            "females": 41695,
            "total_population": 79262,
            "families_count": 19816,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "المطرية",
            "district_en": "El Matareya",
            "males": 322330,
            "females": 339443,
            "total_population": 661773,
            "families_count": 165443,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "عين شمس",
            "district_en": "Ain Shams",
            "males": 332240,
            "females": 342689,
            "total_population": 674929,
            "families_count": 168732,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "السلام 1",
            "district_en": "El Salam 1",
            "males": 256774,
            "females": 271243,
            "total_population": 528017,
            "families_count": 132004,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "السلام 2",
            "district_en": "El Salam 2",
            "males": 81427,
            "females": 87458,
            "total_population": 168885,
            "families_count": 42221,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشرقية",
            "district_ar": "المرج",
            "district_en": "El Marg",
            "males": 429106,
            "females": 448172,
            "total_population": 877278,
            "families_count": 219320,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "غرب القاهرة",
            "district_en": "West Cairo",
            "males": 14625,
            "females": 13415,
            "total_population": 28040,
            "families_count": 7010,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "عابدين",
            "district_en": "Abdeen",
            "males": 23300,
            "females": 21027,
            "total_population": 44327,
            "families_count": 11082,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "الأزبكية",
            "district_en": "El Azbakeya",
            "males": 11108,
            "females": 10611,
            "total_population": 21719,
            "families_count": 5430,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "وسط القاهرة",
            "district_en": "Central Cairo",
            "males": 51184,
            "females": 53017,
            "total_population": 104201,
            "families_count": 26050,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "الموسكى",
            "district_en": "El Muski",
            "males": 9385,
            "females": 8927,
            "total_population": 18312,
            "families_count": 4578,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "باب الشعرية",
            "district_en": "Bab El Shariya",
            "males": 24904,
            "females": 26361,
            "total_population": 51265,
            "families_count": 12816,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "الوايلى",
            "district_en": "El Wayli",
            "males": 84227,
            "females": 81885,
            "total_population": 166112,
            "families_count": 41528,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "بولاق",
            "district_en": "Bulaq",
            "males": 26715,
            "females": 26191,
            "total_population": 52906,
            "families_count": 13227,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الغربية",
            "district_ar": "منشأة ناصر",
            "district_en": "Manshiyat Naser",
            "males": 138351,
            "females": 145449,
            "total_population": 283800,
            "families_count": 70950,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "شبرا",
            "district_en": "Shubra",
            "males": 42612,
            "females": 41666,
            "total_population": 84278,
            "families_count": 21070,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "الساحل",
            "district_en": "El Sahel",
            "males": 171520,
            "females": 176088,
            "total_population": 347608,
            "families_count": 86902,
            "avg_family_size": 4.0,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar":

            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "النزهة",
            "green_parks_sqm": 304800,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "عين شمس",
            "green_parks_sqm": 40761,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 1,
        },
        {
            "district_ar": "شرق مدينة نصر",
            "green_parks_sqm": 466045,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "غرب مدينة نصر",
            "green_parks_sqm": 30685,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "المطرية",
            "green_parks_sqm": 6300,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 1,
        },
        {
            "district_ar": "السلام 1",
            "green_parks_sqm": 36500,
            "dump_sites": 0,
            "sanitary_landfills": 1,
            "recycling_plants": 1,
            "transfer_stations": 0,
        },
        {
            "district_ar": "السلام 2",
            "green_parks_sqm": 52500,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "المرج",
            "green_parks_sqm": 2500,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "منشأة ناصر",
            "green_parks_sqm": 8850,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 1,
        },
        {
            "district_ar": "عابدين",
            "green_parks_sqm": 18578,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الأزبكية",
            "green_parks_sqm": 12735,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "باب الشعرية",
            "green_parks_sqm": 5127,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "وسط القاهرة",
            "green_parks_sqm": 14710,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 1,
        },
        {
            "district_ar": "غرب القاهرة",
            "green_parks_sqm": 11450,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "بولاق",
            "green_parks_sqm": 6580,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الوايلى",
            "green_parks_sqm": 10250,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "شبرا",
            "green_parks_sqm": 4516,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الساحل",
            "green_parks_sqm": 49550,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "حدائق القبة",
            "green_parks_sqm": 42573,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 2,
        },
        {
            "district_ar": "الأميرية",
            "green_parks_sqm": 10200,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الشرابية",
            "green_parks_sqm": 11100,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الزيتون",
            "green_parks_sqm": 11815,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الزاوية الحمراء",
            "green_parks_sqm": 65010,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "الخليفة",
            "green_parks_sqm": 14820,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 1,
        },
        {
            "district_ar": "المقطم",
            "green_parks_sqm": 10600,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "البساتين",
            "green_parks_sqm": 119723.5,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "حلوان",
            "green_parks_sqm": 200800,
            "dump_sites": 1,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "المعصرة",
            "green_parks_sqm": 37005,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "التبين",
            "green_parks_sqm": 67194,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "طرة",
            "green_parks_sqm": 7040,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "المعادى",
            "green_parks_sqm": 130250,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "دار السلام",
            "green_parks_sqm": 14300,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "السيدة زينب",
            "green_parks_sqm": 7425,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
        {
            "district_ar": "15 مايو",
            "green_parks_sqm": 0,
            "dump_sites": 0,
            "sanitary_landfills": 1,
            "recycling_plants": 1,
            "transfer_stations": 0,
        },
        {
            "district_ar": "مصر القديمة",
            "green_parks_sqm": 426374,
            "dump_sites": 0,
            "sanitary_landfills": 0,
            "recycling_plants": 0,
            "transfer_stations": 0,
        },
    ],
    "cairo_waste_management_workforce": [
        # بيانات معدات وعمالة شركات وجمعيات النظافة
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "شبرا",
            "cleaning_societies_equipment": 24,
            "cleaning_societies_workers": 119,
            "companies_equipment": 0,
            "companies_workers": 0,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "الساحل",
            "cleaning_societies_equipment": 58,
            "cleaning_societies_workers": 359,
            "companies_equipment": 26,
            "companies_workers": 138,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "روض الفرج",
            "cleaning_societies_equipment": 30,
            "cleaning_societies_workers": 192,
            "companies_equipment": 15,
            "companies_workers": 66,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "الزيتون",
            "cleaning_societies_equipment": 6,
            "cleaning_societies_workers": 54,
            "companies_equipment": 19,
            "companies_workers": 235,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "حدائق القبة",
            "cleaning_societies_equipment": 65,
            "cleaning_societies_workers": 440,
            "companies_equipment": 0,
            "companies_workers": 0,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "الشرابية",
            "cleaning_societies_equipment": 0,
            "cleaning_societies_workers": 0,
            "companies_equipment": 29,
            "companies_workers": 261,
        },
        {
            "zone": "المنطقة الشمالية",
            "district_ar": "الزاوية الحمراء",
            "cleaning_societies_equipment": 14,
            "cleaning_societies_workers": 119,
            "companies_equipment": 34,
            "companies_workers": 255,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "السيدة زينب",
            "cleaning_societies_equipment": 34,
            "cleaning_societies_workers": 175,
            "companies_equipment": 22,
            "companies_workers": 101,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "الخليفة",
            "cleaning_societies_equipment": 43,
            "cleaning_societies_workers": 286,
            "companies_equipment": 0,
            "companies_workers": 0,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "المقطم",
            "cleaning_societies_equipment": 83,
            "cleaning_societies_workers": 613,
            "companies_equipment": 0,
            "companies_workers": 0,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "مصر القديمة",
            "cleaning_societies_equipment": 107,
            "cleaning_societies_workers": 659,
            "companies_equipment": 8,
            "companies_workers": 46,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "البساتين",
            "cleaning_societies_equipment": 197,
            "cleaning_societies_workers": 1404,
            "companies_equipment": 32,
            "companies_workers": 128,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "دار السلام",
            "cleaning_societies_equipment": 184,
            "cleaning_societies_workers": 1233,
            "companies_equipment": 9,
            "companies_workers": 70,
        },
        {
            "zone": "المنطقة الجنوبية",
            "district_ar": "المعادى وطرة",
            "cleaning_societies_equipment": 65,
            "cleaning_societies_workers": 461,
            "companies_equipment": 1,
            "companies_workers": 39,
        },
    ],
    "cairo_microbus_routes_auction": [
        # مزايدات وخطوط الميكروباص
        {
            "route_id": "ROUTE-01",
            "origin": "السلام (El-Salam)",
            "destination": "مدينة حدائق العاصمة (Capital Gardens)",
            "vehicles_count": 10,
            "auction_date": "2026-07-27",
            "bid_bond_egp": 50000,
            "booklet_price_egp": 299,
            "plate_requirement": "لوحات أجرة القاهرة فقط",
            "managing_entity": "الإدارة العامة لموقف سيارات أجرة الأقاليم",
        },
        {
            "route_id": "ROUTE-02",
            "origin": "السلام (El-Salam)",
            "destination": "مدينة السادات (Sadat City)",
            "vehicles_count": 20,
            "auction_date": "2026-07-27",
            "bid_bond_egp": 50000,
            "booklet_price_egp": 299,
            "plate_requirement": "لوحات أجرة القاهرة فقط",
            "managing_entity": "الإدارة العامة لموقف سيارات أجرة الأقاليم",
        },
    ],
    "cairo_digital_governance_complaints": [
        # منظومة الشكاوى والحوكمة الرقمية
        {
            "system_name": "منظومة الشكاوى الموحدة / بوابة منارة",
            "category": "الأكشاك والفاترينات والمرافق",
            "entity_responsible": "إدارة نظم ومعلومات الأحياء (38 حي)",
            "status_july_2026": (
                "الرد الكامل على كافة الشكاوى الواردة ببرنامج مجلس الوزراء وبوابة"
                " منارة"
            ),
            "spatial_integration": (
                "38 حي خرائط إحداثيات + 52 طبقة خدمات GIS (XLS/GDB)"
            ),
        },
        {
            "system_name": "منظومة شكاوى تقنين أوضاع اليد",
            "category": (
                "مخالفات التقنين والتعطيل والإسغالات (قانون 144 لسنة 2017 وقانون"
                " 168 لسنة 2025)"
            ),
            "entity_responsible": (
                "الإدارة المركزية لنظم المعلومات والتحول الرقمي"
            ),
            "status_july_2026": (
                "تنسيق تلقي البلاغات والشكاوى عبر nplr.estrdad.gov.eg لمتابعة"
                " التنفيذ وسرعة الإنجاز"
            ),
            "spatial_integration": (
                "مربوطة بلجنة حصر أصول أملاك الدولة والتصوير الرقمي"
            ),
        },
        {
            "system_name": "منظومة المراقبة المرئية والكاميرات",
            "category": "منع إلقاء المخلفات الصلبة والسيارات المعطلة",
            "entity_responsible": (
                "إدارة الشبكات واللجنة القومية الدائمة للرصد المرئي"
            ),
            "status_july_2026": (
                "مراجعة يومية لكاميرات محطات الوقود والربط بـ VPN والراوترات"
                " لمنع الإلقاء عشوائياً"
            ),
            "spatial_integration": (
                "توقيع إحداثيات ومتابعة مباشرة مع شرطة المرافق"
            ),
        },
    ],
    "cairo_natural_population_growth": [
        # معدلات النمو السكاني والزيادة الطبيعية 2021-2025
        {
            "year": 2021,
            "birth_rate_per_1000": 19.3,
            "death_rate_per_1000": 11.2,
            "natural_growth_rate_per_1000": 8.1,
            "source": "CAPMAS (April 2026)",
        },
        {
            "year": 2022,
            "birth_rate_per_1000": 19.4,
            "death_rate_per_1000": 9.6,
            "natural_growth_rate_per_1000": 9.8,
            "source": "CAPMAS (April 2026)",
        },
        {
            "year": 2023,
            "birth_rate_per_1000": 19.0,
            "death_rate_per_1000": 9.4,
            "natural_growth_rate_per_1000": 9.6,
            "source": "CAPMAS (April 2026)",
        },
        {
            "year": 2024,
            "birth_rate_per_1000": 18.5,
            "death_rate_per_1000": 9.8,
            "natural_growth_rate_per_1000": 8.7,
            "source": "CAPMAS (April 2026)",
        },
        {
            "year": 2025,
            "birth_rate_per_1000": 18.3,
            "death_rate_per_1000": 10.3,
            "natural_growth_rate_per_1000": 8.0,
            "source": "CAPMAS (April 2026)",
        },
    ],
}

# 3. إنشاء المجلدات الفرعية داخل data وحفظ ملفات CSV وبناء قاعدة البيانات SQLite
db_path = os.path.join(base_dir, "urbanmind_ai.db")
conn = sqlite3.connect(db_path)

print("⚙️ Creating independent folders and saving CSV files inside 'data'...\n")

for folder_name, data in datasets.items():
    # إنشاء مجلد مستقل لكل اسم ملف
    folder_path = os.path.join(base_dir, folder_name)
    os.makedirs(folder_path, exist_ok=True)

    # حفظ ملف الـ CSV داخل المجلد المخصص
    csv_file_path = os.path.join(folder_path, f"{folder_name}.csv")
    df = pd.DataFrame(data)
    df.to_csv(csv_file_path, index=False, encoding="utf-8-sig")

    # حفظ وتحديث الجدول في قاعدة بيانات SQLite
    df.to_sql(folder_name, conn, if_exists="replace", index=False)

    print(f"📁 Folder: {folder_path}")
    print(f"   └── 📄 CSV: {csv_file_path}")

conn.close()

print("\n" + "=" * 70)
print(
    "🎉 ALL DATASETS HAVE BEEN CREATED IN SEPARATE FOLDERS & INTEGRATED INTO"
    " SQLITE!"
)
print("=" * 70)
# Out:
# 📌 ضعي ملف الـ PDF الخاص بكِ الآن في هذا المسار ليصل إليه الكود مباشرة:
# 👉 D:\Courses\MachineLearning\Depi\Final Project\data\pdf_reports
#
# ⚙️ Creating independent folders and saving CSV files inside 'data'...
#
# 📁 Folder: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_population_districts
#    └── 📄 CSV: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_population_districts\cairo_population_districts.csv
# 📁 Folder: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_environmental_infrastructure
#    └── 📄 CSV: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_environmental_infrastructure\cairo_environmental_infrastructure.csv
# 📁 Folder: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_waste_management_workforce
#    └── 📄 CSV: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_waste_management_workforce\cairo_waste_management_workforce.csv
# 📁 Folder: D:\Courses\MachineLearning\Depi\Final Project\data\cairo_microbus_routes_auction
# ...
